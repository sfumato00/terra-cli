# %%
from pathlib import Path
import terra

FIXTURES = Path('/Users/l/repos/openinfer/oi-terraform/terraform/environments/dev')

# %%
## 1. Load state and inspect resources

# %%
plan = terra.load.plan_json(FIXTURES / 'plan.json')
terra.frame.summary(plan)
# Out:
# {'add': 0, 'change': 1, 'destroy': 0, 'no-op': 32}
